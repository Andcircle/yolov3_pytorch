# %% [markdown]
# <a href="https://colab.research.google.com/github/Andcircle/yolov3_pytorch/blob/traffic_sign_colab/traffic_sign_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python3 train.py --pretrained_weights weights/yolov3-tiny.weights
# Out:
# Namespace(batch_size=2, checkpoint_interval=1, compute_map=False, data_config='config/coco_test.data', epochs=5, evaluation_interval=1, experiment='yolov3', gradient_accumulations=1, img_size=416, logdir='logs', model_def='config/yolov3-tiny.cfg', multiscale_training=True, n_cpu=8, pretrained_weights='weights/yolov3-tiny.weights', sparse_l1_rate=0.0001, sparsity_training=True, verbose=False)
# Training Epoch 0:   0%|                                   | 0/2 [00:00<?, ?it/s]/workspace/PyTorch-YOLOv3/models.py:166: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if grid_size != self.grid_size:
# ...

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# %cd /workspace/PyTorch-YOLOv3
# %pwd
# %tensorboard --logdir logs
# Out:
# /workspace/PyTorch-YOLOv3
# Reusing TensorBoard on port 6009 (pid 657946), started 0:02:34 ago. (Use '!kill 657946' to kill it.)
#       <iframe id="tensorboard-frame-eaf7f8d28ba89d9f" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-eaf7f8d28ba89d9f");
#           const url = new URL("/", window.location);
#           const port = 6009;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
